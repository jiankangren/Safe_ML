# %%
# Package Usage
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier

# %%
df = sns.load_dataset('iris')

X=np.linspace(0, 10, num=10000)
Y=map(lambda x:np.sin(x)+np.random.normal(0,0.2),X)
Y=np.array(Y)

df = pd.DataFrame()
df['X']=X
df['Y']=Y
plt.scatter(X,Y,**{"marker": "D","s": 1})


# sns.lmplot('X', # Horizontal axis
#            'Y', # Vertical axis
#            data=df, # Data source
#            fit_reg=False, # Don't fix a regression line
#            scatter_kws={"marker": "D", # Set marker style
#                         "s": 10}) # S marker size

# %%
idx = np.random.permutation(df['X'].size)
idx_train, idx_cal, idx_test = idx[:3000], idx[300:3999], idx[3999:]
print X.shape,Y.shape
print X.reshape(-1 ,1).shape
# Out:
# (10000,) (10000,)
# (10000, 1)

# %%
from nonconformist.nc import Nc_Reg_Creator
from sklearn.ensemble import RandomForestRegressor


# model = RandomForestRegressor()
# nc_regressor = Nc_Reg_Creator.create_nc(model)

# Z=X[np.newaxis,:]
# print Z.shape


# print X.size
nc_regressor.fit(X.reshape(-1 ,1)[idx_train], Y[idx_train])

nc_regressor.calibrate(X.reshape(-1 ,1)[idx_cal], Y[idx_cal])
nc_set=nc_regressor.cal_scores
prediction =nc_regressor.predict(X.reshape(-1 ,1)[idx_test],nc_set,significance=0.02)

# print(prediction[:5, :][0])
d=prediction[2][1]-prediction[2][0]
# Out:
# 0.890938417855

# %%
print prediction.shape
Ys=np.split(prediction, 2, axis=1)
Ys0=Ys[0].reshape(1,6001)[0]
Ys1=Ys[1].reshape(1,6001)[0]
df1 = pd.DataFrame()
df1['X']=X[idx_test]
df1['Y']=Y[idx_test]
# df['Ys'][idx_test]=Ys0
YUB=map(lambda x:np.sin(x)+prediction[0][0][1]-prediction[0][0][0], X[idx_test])



plt.scatter(df1['X'],df1['Y'],**{"marker": "D","s": 1})
plt.scatter(df1['X'],Ys0,**{"marker": "D","s": 1})

plt.scatter(df1['X'],Ys1,**{"marker": "D","s": 1})



#
# Out:
# (6001, 2)
