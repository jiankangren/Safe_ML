# %% [markdown]
# ## DecisionTree.CLTree
# Attribute
#     ----------
#     feature :   np.array([int])
#         feature[i] denotes the split  index for node i
#     threshold_left : np.array([float])
#         threshold_left[i]:denotes the split threshold  for node i <=sL
#     threshold_right : np.array([float])
#         threshold_left[i]:denotes the split threshold  for node i >=sL:
#     children_left :  np.array([int])
#         children_left[i] holds the node id of the left child of node i.
#     children_right :  np.array([int])
#         children_right[i] holds the node id of the left child of node i.
#     leaves : dict
#         Contains leaf nodes
#     vol : float
#         Volume of the tree  = prod(x_imax-x_imin for i)
#     total_sample: int
#         The number of total training samples
#     root_gain: float
#         The initial score (1-p0^2-p1^2)  (- /minus ) the best score for the first split
#     density {ID: density}
#     density_X {ID: density}
#
#     Examples
#          0
#        1    2
#       3 4  5 6
#     7
#     feature :   np.array([0,1,1,2,1,0,1])
#     children_left  [1,3,5,7,-1,-1,-1,-1]
#     children_right  [2,4,6,-1,-1,-1,-1,-1]
#     threshold  [0.5,0.19,1,3...]
#
#     Parameter:
#     ----------
#     X : np.darray
#         The input data
#     min_samples_leaf : int
#         The minimum number of samples required to be at a leaf node:
#     max_depth : int
#         maximum depth of the tree to stop
#     gain_ratio_threshold: float
#         If (ini_score-best_score)/root_gain < threshold , then split

# %%
n=500
import numpy as np
from math import floor, ceil
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.datasets import make_moons, make_circles, make_classification
X, y = make_classification(n_samples=n,n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
linearly_separable = (X, y)
moon=make_moons(n_samples=n,noise=0.3, random_state=0)
circle=make_circles(n_samples=n,noise=0.2, factor=0.5, random_state=1)

#---------------
import math
x11=np.linspace(0, 4, num=250)
x12=np.linspace(6, 10, num=250)
x1=np.concatenate((x11, x12), axis=0)
x2=map(lambda x:np.sin(x)+np.random.normal(0,0.2),x1 )
X=np.array([x1,x2]).T
y=[1]*len(x1)
sin=(X,y)
#---------------
data=[linearly_separable,moon,circle,sin]

# %%
from DecisionTree import CLTree
figure = plt.figure(figsize=(27, 7))
i=1
for X,y in data:
    h=0.05
    x1_min, x1_max = X.T[0].min() - .1, X.T[0].max() + .1
    x2_min, x2_max = X.T[1].min() - .1, X.T[1].max() + .1
    xx, yy = np.meshgrid(np.arange(x1_min-1, x1_max+1, h),np.arange(x2_min-1, x2_max+1, h))
    tree=CLTree(criterion='gini',  min_samples_leaf=1, max_depth=30,gain_ratio_threshold=0.02)
    tree.fit(X)
    Z=tree.predict(np.c_[xx.ravel(), yy.ravel()],threshold=tree.ICDF_threshold(0.1))
    Z=Z.reshape(xx.shape)
    ax = plt.subplot(1, 4, i)
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    ax.set_title("Input data")
    ax.scatter(X.T[0], X.T[1], c=y, cmap=cm_bright,edgecolors='k')
    ax.set_xlim(x1_min, x1_max)
    ax.set_ylim(x2_min, x2_max)
    ax.set_xticks(range(int(floor(x1_min)),int(ceil(x1_max))))
    ax.set_yticks(range(int(floor(x2_min)),int(ceil(x2_max))))
    cntr1 = ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)
    cbar0 = plt.colorbar( cntr1,)
    # for leaf_key in tree.leaves.keys():
        # print tree.leaves[leaf_key].X,tree.leaves[leaf_key].depth, leaf_key
    i+=1
plt.tight_layout()
plt.show()

# %%
from RandomForest import *
figure = plt.figure(figsize=(27, 7))
i=1
for X,y in data:
    h=0.05
    x1_min, x1_max = X.T[0].min() - .1, X.T[0].max() + .1
    x2_min, x2_max = X.T[1].min() - .1, X.T[1].max() + .1
    xx, yy = np.meshgrid(np.arange(x1_min-1, x1_max+1, h),np.arange(x2_min-1, x2_max+1, h))
    rf=RandomForestClassifier(nb_trees=10, pec_samples=0.4, max_workers=4,\
    criterion='gini', min_samples_leaf=1, max_depth=30,gain_ratio_threshold=0.01)
    rf.fit(X)
    Z= rf.predict(np.c_[xx.ravel(), yy.ravel()],0.1)
    Z=Z.reshape(xx.shape)
    ax = plt.subplot(1, 4, i)
#     cm = plt.cm.RdBu
    cm= plt.cm.tab20c
    ax.set_title("Input data")
    ax.scatter(X.T[0], X.T[1], c=y, cmap=cm_bright,edgecolors='k')
    ax.set_xlim(x1_min, x1_max)
    ax.set_ylim(x2_min, x2_max)
    ax.set_xticks(range(int(floor(x1_min)),int(ceil(x1_max))))
    ax.set_yticks(range(int(floor(x2_min)),int(ceil(x2_max))))
    cntr1 = ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)
    cbar0 = plt.colorbar( cntr1,)
    # for leaf_key in tree.leaves.keys():
        # print tree.leaves[leaf_key].X,tree.leaves[leaf_key].depth, leaf_key
    i+=1
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(5, 5))
h=0.05
# X= np.array([[0,0],[1,1,],[3,3],[4,4],[6,6],[7,7],[9,9],[10,10]])
# y=np.ones(len(X))

x1_min, x1_max = X.T[0].min() - .1, X.T[0].max() + .1
x2_min, x2_max = X.T[1].min() - .1, X.T[1].max() + .1
xx, yy = np.meshgrid(np.arange(x1_min-1, x1_max+1, h),np.arange(x2_min-1, x2_max+1, h))
tree=CLTree(criterion='gini',  min_samples_leaf=1, max_depth=10,gain_ratio_threshold=0.01)
tree.fit(X)
Z=tree.predict(np.c_[xx.ravel(), yy.ravel()],threshold=tree.ICDF_threshold(0.2))
Z=Z.reshape(xx.shape)
ax = plt.subplot(1, 1, 1)
cm = plt.cm.tab20c
ax.set_title("Input data")
ax.scatter(X.T[0], X.T[1], c=y, cmap=cm,edgecolors='k')
ax.set_xlim(x1_min, x1_max)
ax.set_ylim(x2_min, x2_max)
ax.set_xticks(range(int(floor(x1_min)),int(ceil(x1_max))))
ax.set_yticks(range(int(floor(x2_min)),int(ceil(x2_max))))
cntr1 = ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)
cbar0 = plt.colorbar( cntr1,)
# for leaf_key in tree.leaves.keys():
#     print '----'
#     print tree.leaves[leaf_key].X
#     print '~~~~'
#     print tree.leaves[leaf_key].feature_limit_X

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from matplotlib import cm
from sklearn.preprocessing import StandardScaler
import time

mydata=pd.read_csv('./data/2.csv').values
X=np.array(mydata[:,0:2])
y=mydata[:,2]
label=list(set(y))
y=np.array(y)
index=[0]*len(label)
for i in range(0,len(label)):
    index[i]=(y==label[i])
    y[index[i]]=int(i) 
    
figure = plt.figure(figsize=(24, 12))
h=0.02
x1_min, x1_max = X.T[0].min() - .1, X.T[0].max() + .1
x2_min, x2_max =X.T[1].min() - .1, X.T[1].max() + .1
xx, yy = np.meshgrid(np.arange(x1_min-1, x1_max+1, h),np.arange(x2_min-1, x2_max+1, h))


ax = plt.subplot(1, 2, 1)
cmap = plt.cm.tab20c
# cmap = cm.cool
# colors =['r','g','b','pink']

# ax.set_title("Input data")
ax.set_ylim(x2_min, x2_max)
ax.set_xticks(range(int(floor(x1_min)),int(ceil(x1_max))))
ax.set_yticks(range(int(floor(x2_min)),int(ceil(x2_max))))
ax.set_xlabel('Sensor Reading From Front Sensor',size=20)
ax.set_ylabel('Sensor Reading From Left Sensor',size=20)
markers=['.','.','.','.']
for i in range(0,len(label)):
    ax.scatter(X[index[i]].T[0], X[index[i]].T[1], cmap=cmap,marker=markers[i],label=label[i])
    ax.set_xlim(x1_min, x1_max)
    

ax.legend(prop={'size': 30})

ax = plt.subplot(1, 2, 2)
colors =['pink','pink','pink','pink']
for i in range(0,len(label)):
    ax.scatter(X[index[i]].T[0], X[index[i]].T[1], c=colors[i],marker=markers[i],label=label[i])
    ax.set_xlim(x1_min, x1_max)
rf=RandomForestClassifier(nb_trees=50, pec_samples=0.4, max_workers=4,\
    criterion='gini', min_samples_leaf=1, max_depth=30,gain_ratio_threshold=0.001,\
                           max_feature_p=1,max_try_p=0.3)
start_time=time.time()
rf.fit(X)
print 'Training Time',  time.time()-start_time
start_time=time.time()
Z= rf.predict(np.c_[xx.ravel(), yy.ravel()],0.05)
print 'Predict Time',  time.time()-start_time

Z=Z.reshape(xx.shape)
cntr1 = ax.contourf(xx, yy, Z, cmap=cmap, alpha=.8)
cbar0 = plt.colorbar( cntr1,)
plt.tight_layout()
plt.show()
# Out:
# Training Time 14.3823611736
# Predict Time 266.63244319

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

mydata=pd.read_csv('./data/2.csv').values
X=np.array(mydata[:,0:2])
y=mydata[:,2]

X_train, X_test, y_train, y_test = \
        train_test_split(X, y, test_size=.25, random_state=42)   
mlp = MLPClassifier(hidden_layer_sizes=(100,100,), max_iter=50, alpha=1e-4,
                    solver='adam', verbose=10, tol=1e-5, random_state=1,
                    learning_rate_init=.1)
mlp.fit(X_train, y_train)

print("Training set score: %f" % mlp.score(X_train, y_train))

print("Test set score: %f" % mlp.score(X_test, y_test))

figure = plt.figure(figsize=(25, 15))

h=0.2
x1_min, x1_max = X.T[0].min() - .1, X.T[0].max() + .1
x2_min, x2_max =X.T[1].min() - .1, X.T[1].max() + .1
xx, yy = np.meshgrid(np.arange(x1_min-1, x1_max+1, h),np.arange(x2_min-1, x2_max+1, h))

# for i in xrange(0,4):
#     ax = plt.subplot(1, 4, i+1)
for i in xrange(0,1):
    ax = plt.subplot(1, 1, 1)
    cmap = plt.cm.RdBu
    cmap = plt.cm.Set2
    cmap = plt.cm.tab20c
    colors =['black','g','b','purple']
    # colors =['pink','pink','pink','pink']
# ax.set_title("Input data")
    ax.set_ylim(x2_min, x2_max)
    ax.set_xticks(range(int(floor(x1_min)),int(ceil(x1_max))))
    ax.set_yticks(range(int(floor(x2_min)),int(ceil(x2_max))))
    ax.set_xlabel('Sensor Reading From Front Sensor',size=20)
    ax.set_ylabel('Sensor Reading From Left Sensor',size=20)
    markers=['.','+','o',',']
    for j in range(0,len(label)):
        ax.scatter(X[index[j]].T[0], X[index[j]].T[1], c=colors[j],marker=markers[j],label=label[j])
        ax.set_xlim(x1_min, x1_max)
#     Z = mlp.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, i]
#     Z = Z.reshape(xx.shape)
#     cntr1 = ax.contourf(xx, yy, Z, cmap=cmap, alpha=.8)
#     cbar0 = plt.colorbar( cntr1,)

label=mlp.classes_
y_pred= np.array(mlp.predict_proba(X))
y_pred_index=np.argmax(y_pred, axis=1)
y_h= np.array([ [label[i],yt,p[i]] for i,p,yt in zip(y_pred_index,y_pred,y)])    
index_wrong=(y_h.T[0]!=y_h.T[1])
print index_wrong

ax = plt.subplot(1, 1, 1)
ax.scatter(X[index_wrong].T[0], X[index_wrong].T[1], c='m',marker='*')

plt.tight_layout()
plt.show()
# Out:
# Iteration 1, loss = 1.44288864
# Iteration 2, loss = 0.48734509
# Iteration 3, loss = 0.29523536
# Iteration 4, loss = 0.18442884
# Iteration 5, loss = 0.15416854
# Iteration 6, loss = 0.16191649
# Iteration 7, loss = 0.09612263
# Iteration 8, loss = 0.19284424
# Iteration 9, loss = 0.18147704
# Iteration 10, loss = 0.10291561
# Training loss did not improve more than tol=0.000010 for two consecutive epochs. Stopping.
# Training set score: 0.983623
# Test set score: 0.980205
# /Applications/anaconda2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
from sklearn.model_selection import cross_val_score
label=mlp.classes_
# print   results
# print label

print y_h[index_wrong]
# print X[index_wrong]
p2=rf.predict(X[index_wrong],0.1)
print p2
# print len(y_h)
# print (y_h.T[0]==y_h.T[1]).sum()
# print y_h[y_h.T[0]!=y_h.T[1]]
# Out:
# [['Sharp-Right-Turn' 'Slight-Right-Turn' '0.649727263409']
#  ['Slight-Right-Turn' 'Move-Forward' '0.632409689108']
#  ['Slight-Right-Turn' 'Move-Forward' '0.592264640462']
#  ['Slight-Right-Turn' 'Move-Forward' '0.572229449775']
#  ['Slight-Right-Turn' 'Move-Forward' '0.529649505748']
#  ['Slight-Right-Turn' 'Move-Forward' '0.597547808162']
#  ['Slight-Right-Turn' 'Move-Forward' '0.531392936782']
#  ['Slight-Right-Turn' 'Move-Forward' '0.624046039309']
#  ['Slight-Right-Turn' 'Move-Forward' '0.582865367479']
#  ['Slight-Right-Turn' 'Move-Forward' '0.562711591968']
#  ['Slight-Right-Turn' 'Move-Forward' '0.520166455503']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.556947113209']
#  ['Slight-Right-Turn' 'Move-Forward' '0.553756383948']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.532114655247']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.503473348495']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.52352917035']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.558599980513']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.578293734855']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.595420968698']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.631197793532']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.663438829053']
#  ['Move-Forward' 'Slight-Left-Turn' '0.507550464029']
#  ['Move-Forward' 'Slight-Left-Turn' '0.951454972211']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.710849881046']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.751839492347']
#  ['Sharp-Right-Turn' 'Slight-Right-Turn' '0.762712582787']
#  ['Sharp-Right-Turn' 'Slight-Right-Turn' '0.775098208752']
#  ['Sharp-Right-Turn' 'Slight-Right-Turn' '0.785112549956']
#  ['Slight-Right-Turn' 'Move-Forward' '0.576313865319']
#  ['Slight-Left-Turn' 'Move-Forward' '0.668571314376']
#  ['Slight-Left-Turn' 'Move-Forward' '0.670211729974']
#  ['Sharp-Right-Turn' 'Slight-Left-Turn' '0.609602622991']
#  ['Slight-Right-Turn' 'Move-Forward' '0.56754422802']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.678482511746']
#  ['Slight-Right-Turn' 'Move-Forward' '0.627226432695']
#  ['Slight-Right-Turn' 'Move-Forward' '0.564632661857']
#  ['Move-Forward' 'Slight-Right-Turn' '0.504905932947']
#  ['Move-Forward' 'Slight-Right-Turn' '0.638474685914']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.54232316453']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.594602460125']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.553166362633']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.561302393238']
#  ['Slight-Right-Turn' 'Move-Forward' '0.623870855795']
#  ['Slight-Right-Turn' 'Move-Forward' '0.603996529914']
#  ['Slight-Right-Turn' 'Move-Forward' '0.583772574531']
#  ['Slight-Right-Turn' 'Move-Forward' '0.541051392047']
#  ['Slight-Right-Turn' 'Move-Forward' '0.563416569625']
#  ['Slight-Right-Turn' 'Move-Forward' '0.638963961493']
#  ['Slight-Right-Turn' 'Move-Forward' '0.576597731249']
#  ['Slight-Right-Turn' 'Move-Forward' '0.533912700802']
#  ['Sharp-Right-Turn' 'Slight-Right-Turn' '0.500085876309']
#  ['Slight-Right-Turn' 'Move-Forward' '0.501362151559']
#  ['Sharp-Right-Turn' 'Slight-Right-Turn' '0.762712582787']
#  ['Slight-Right-Turn' 'Move-Forward' '0.603282026092']
#  ['Slight-Right-Turn' 'Move-Forward' '0.573140890917']
#  ['Slight-Right-Turn' 'Move-Forward' '0.508342746242']
#  ['Slight-Right-Turn' 'Move-Forward' '0.594148661709']
#  ['Slight-Right-Turn' 'Move-Forward' '0.574144825077']
#  ['Slight-Right-Turn' 'Move-Forward' '0.531602310808']
#  ['Slight-Left-Turn' 'Move-Forward' '0.553979655757']
#  ['Slight-Left-Turn' 'Move-Forward' '0.620878132672']
#  ['Slight-Left-Turn' 'Move-Forward' '0.646745876316']
#  ['Slight-Left-Turn' 'Move-Forward' '0.640516633508']
#  ['Sharp-Right-Turn' 'Slight-Left-Turn' '0.505262650792']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.520575546859']
#  ['Slight-Right-Turn' 'Move-Forward' '0.627716194558']
#  ['Slight-Right-Turn' 'Move-Forward' '0.607383195712']
#  ['Slight-Right-Turn' 'Move-Forward' '0.565830580942']
#  ['Slight-Right-Turn' 'Move-Forward' '0.51340222617']
#  ['Slight-Right-Turn' 'Move-Forward' '0.600239678053']
#  ['Slight-Right-Turn' 'Move-Forward' '0.558113131673']
#  ['Slight-Right-Turn' 'Move-Forward' '0.541578250408']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.578171084795']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.534829273511']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.73174587527']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.618129890588']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.53729490526']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.721492634081']
#  ['Slight-Right-Turn' 'Move-Forward' '0.645047964899']
#  ['Slight-Right-Turn' 'Move-Forward' '0.61535367289']
#  ['Slight-Right-Turn' 'Move-Forward' '0.574779677078']
#  ['Slight-Right-Turn' 'Move-Forward' '0.509459388674']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.409277715065']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.660608484601']
#  ['Slight-Right-Turn' 'Move-Forward' '0.629503831269']
#  ['Slight-Right-Turn' 'Move-Forward' '0.566611795481']
#  ['Slight-Right-Turn' 'Move-Forward' '0.523940263589']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.793285003336']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.769261147024']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.769261147024']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.782722470546']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.81529333352']
#  ['Sharp-Right-Turn' 'Move-Forward' '0.816715826227']
#  ['Sharp-Right-Turn' 'Slight-Left-Turn' '0.997997823525']]
# [ 0.8   1.    1.    0.98  1.    1.    0.98  1.    1.    1.    1.    1.
#   0.42  0.94  1.    1.    1.    1.    1.    1.    1.    0.16  0.04  0.96
#   0.96  0.96  0.96  0.98  1.    0.2   0.44  0.44  0.12  0.98  0.74  0.54
#   0.    0.    1.    0.96  1.    0.98  1.    1.    1.    1.    0.84  0.96
#   0.96  0.98  0.94  0.64  0.96  1.    0.98  1.    0.86  0.9   0.9   0.26
#   0.3   0.32  0.4   0.68  1.    1.    1.    1.    1.    1.    1.    0.58
#   0.84  1.    0.98  0.94  0.94  1.    1.    0.98  0.98  1.    0.22  0.98
#   0.98  1.    1.    0.98  1.    1.    1.    1.    1.    0.  ]
